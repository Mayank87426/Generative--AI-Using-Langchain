# %%
import langchain
langchain.__version__
# Out:
# '1.3.1'

# %%
import os
from dotenv import load_dotenv
load_dotenv()


os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
os.environ["GEMINI_API_KEY"]=os.getenv("GEMINI_API_KEY")

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI


chat = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.7
)

response = chat.invoke("What is LangChain?")

print(response.content)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# **LangChain** is an open-source development framework designed to simplify the creation of applications powered by large language models (LLMs).
#
# In essence, it acts as a **toolkit or abstraction layer** that helps developers connect LLMs to external data sources, computation, and other tools, allowing them to build more complex, powerful, and context-aware LLM-driven applications than what's possible with a standalone LLM.
#
# ### Why is LangChain Needed?
#
# While LLMs like GPT-4 or Claude are incredibly powerful, they have limitations:
#
# 1.  **Lack of Real-time Data:** Their knowledge is often cut off at their last training date.
# 2.  **Inability to Perform Actions:** They can generate text, but they can't browse the web, send emails, or query a database.
# 3.  **Limited Context Window:** For long conversations or complex tasks, they can "forget" earlier parts of the interaction.
# 4.  **Complexity of Orchestration:** Building sophisticated applications often requires multiple steps, conditional logic, and interaction with various APIs.
#
# LangChain addresses these limitations by providing a structured way to combine LLMs with other components.
#
# ### Key Concepts and Components of LangChain:
#
# LangChain is built around several modular components that can be combined in various ways:
#
# 1.  **Models (LLMs & Chat Models):**
#     *   Provides a standardized interface to interact with various LLM providers (OpenAI, Anthropic, Hugging Face, etc.) and different model types (text-completion models, chat models).
#
# 2.  **Prompts:**
#     *   Tools for constructing, managing, and optimizing prompts (e.g., prompt templates, few-shot examples).
#
# 3.  **Chains:**
#     *   Sequences of calls to LLMs or other utilities. A chain allows you to define a series of operations, where the output of one step becomes the input of the next. For example, a chain might take user input, format it into a prompt, send it to an LLM, and then process the LLM's output.
#
# 4.  **Retrieval (Data Augmented Generation - RAG):**
#     *   Components for connecting LLMs to external data. This is crucial for giving LLMs up-to-date, specific, or proprietary information they weren't trained on. It includes:
#         *   **Document Loaders:** To ingest data from various sources (PDFs, websites, databases).
#         *   **Text Splitters:** To break down large documents into smaller chunks suitable for LLMs.
#         *   **Vector Stores:** Databases that store embeddings (numerical representations) of text, allowing for efficient semantic search (e.g., Pinecone, Chroma, FAISS).
#         *   **Retrievers:** To fetch relevant data chunks from vector stores based on a query.
#
# 5.  **Agents:**
#     *   The most powerful concept. Agents allow an LLM to dynamically decide *which tools to use* and *in what order* to achieve a goal. Instead of a fixed sequence (like a chain), an agent uses the LLM as a "reasoning engine" to plan and execute steps.
#         *   **Tools:** Functions or APIs that an agent can call (e.g., a search engine, a calculator, a custom API to send an email).
#
# 6.  **Memory:**
#     *   Mechanisms to persist state between calls of a chain or agent, allowing for conversational context (e.g., remembering previous turns in a chat).
#
# ### What Can You Build with LangChain?
#
# LangChain enables the creation of a wide range of LLM applications, including:
#
# *   **Question Answering over Documents:** Chatbots that can answer questions based on your specific PDFs, internal wikis, or personal notes.
# *   **Intelligent Agents:** Systems that can perform multi-step tasks by combining LLM reasoning with external tools (e.g., "Find me restaurants in Paris, check their reviews, and book a table at the best-rated one available tonight.").
# *   **Personalized Chatbots:** Assistants that remember past interactions and user preferences.
# *   **Data Analysis Tools:** LLM-powered interfaces to query and analyze structured or unstructured data.
# *   **Summarization and Extraction:** Advanced systems for summarizing long articles or extracting specific information from text.
#
# In summary, LangChain simplifies the process of building sophisticated LLM applications by providing a modular, extensible, and powerful framework to connect LLMs with data, tools, and complex logic. It's available in both Python and JavaScript.

# %%
from langchain.chat_models import init_chat_model
